# %%
import numpy as np    
import time

a = np.zeros(166464)
start = time.time()
audio_fft = np.fft.fft(a,len(a))                          
print("tiempo: %fs"%(time.time() -start))


a = np.zeros(166400)
start = time.time()
audio_fft = np.fft.fft(a,len(a))                          
print("tiempo: %fs"%(time.time() -start))

a = np.zeros(2**16)
start = time.time()
audio_fft = np.fft.fft(a,len(a))                          
print("tiempo: %fs"%(time.time() -start))

a = np.zeros(2**17)
start = time.time()
audio_fft = np.fft.fft(a,len(a))                          
print("tiempo: %fs"%(time.time() -start))

a = np.zeros(1+2**16)
start = time.time()
audio_fft = np.fft.fft(a,len(a))                          
print("tiempo: %fs"%(time.time() -start))
